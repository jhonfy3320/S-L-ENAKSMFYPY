# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

from sklearn.cluster import MiniBatchKMeans

# %%
if __name__ == '__main__':
    dataset = pd.read_csv('/home/jhonfypy/CursoML_Scikit_learni_jf/candy.csv')
    print(dataset.head(20))
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# 5                   Almond Joy          1       0        0               1
# 6                    Baby Ruth          1       0        1               1
# 7           Boston Baked Beans          0       0        0               1
# 8                   Candy Corn          0       0        0               0
# 9           Caramel Apple Pops          0       1        1               0
# 10             Charleston Chew          1       0        0               0
# ...

# %% [markdown]
# Aca no se necesita datos de entrenmiento y prueba, porque es aprendizaje no supervisado por eso no es necesario partir nuetro dataset en entrenamiento y prueba
# Lo que se hace en un modelo de IA no supervisado es tomar todos los valores que tenemos y los emviamos directamente a MiniBatchKMeans para que los prosece

# %%
#configurando los 4 centros en los cuales queremos organizar nuetras variables 
X = dataset.drop('competitorname', axis=1)

kmeans = MiniBatchKMeans(n_clusters=4, batch_size=8).fit(X)
print('Total de centros: ', len(kmeans.cluster_centers_))
print('='*68)
#Devolviendo uno de los arrglos, con una de las categorias  
print(kmeans.predict(X))

dataset['group'] = kmeans.predict(X)
print(dataset)
# Out:
# /home/jhonfypy/anaconda3/envs/Scikit-learni-envjf/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1930: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=3)
# Total de centros:  4
# ...
# [1 1 0 3 2 2 2 0 3 0 3 0 0 3 3 3 3 3 2 0 2 3 2 2 2 2 0 2 1 3 3 2 1 1 3 2 1
#  2 1 3 2 2 1 1 0 3 3 1 3 3 3 1 1 1 1 0 1 0 3 0 1 2 3 3 1 2 2 2 1 0 0 0 0 2
#  2 3 3 2 3 1 3 3 3 3 2]
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# ...

# %%
dataset['group'] = kmeans.predict(X)
print(dataset)
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# ..                         ...        ...     ...      ...             ...
# 80                   Twizzlers          0       1        0               0
# 81                    Warheads          0       1        0               0
# 82        WelchÕs Fruit Snacks          0       1        0               0
# 83  WertherÕs Original Caramel          0       0        1               0
# 84                    Whoppers          1       0        0               0
#
# ...

# %%
import pandas as pd

from sklearn.cluster import MiniBatchKMeans



X = dataset.drop('competitorname', axis=1)

kmeans = MiniBatchKMeans(n_clusters=4, batch_size=8).fit(X)
print("Total de centros: " , len(kmeans.cluster_centers_))
print("="*64)
print(kmeans.predict(X))

dataset['group'] = kmeans.predict(X)

print(dataset)
# Out:
# /home/jhonfypy/anaconda3/envs/Scikit-learni-envjf/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1930: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=3)
# Total de centros:  4
# ...
# [3 3 0 1 1 1 3 2 1 0 1 0 2 1 1 1 1 1 3 0 1 1 3 3 3 3 2 3 3 1 1 1 3 3 1 3 3
#  3 3 1 3 3 3 3 2 1 1 3 0 1 0 3 3 3 3 0 3 0 1 0 3 3 1 1 3 3 3 1 3 0 0 0 2 3
#  1 1 1 1 1 3 1 1 1 1 1]
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# ...

# %%
import seaborn as sns
sns.pairplot(dataset, hue='group')
# Out:
# /home/jhonfypy/anaconda3/envs/Scikit-learni-envjf/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(dataset[['sugarpercent','pricepercent','winpercent','group']], hue = 'group')
# Out:
# /home/jhonfypy/anaconda3/envs/Scikit-learni-envjf/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import numpy as np
from sklearn.cluster import MiniBatchKMeans
from sklearn.datasets import make_blobs

# Generar datos de ejemplo
n_samples = 1000
n_features = 2
n_clusters = 3
X, y = make_blobs(n_samples=n_samples, n_features=n_features, centers=n_clusters, random_state=42)

# Crear un modelo Batch K-Means
batch_kmeans = MiniBatchKMeans(n_clusters=n_clusters, batch_size=100, random_state=42)

# Ajustar el modelo a los datos
batch_kmeans.fit(X)

# Obtener las etiquetas de los clústeres
labels = batch_kmeans.labels_

# Obtener las coordenadas de los centroides
centroids = batch_kmeans.cluster_centers_
# Out:
# /home/jhonfypy/anaconda3/envs/Scikit-learni-envjf/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1930: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=3)
