# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd 

#importamos los modulos especificoa 
from sklearn.decomposition import  KernelPCA 
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
if __name__ == '__main__': # Cargamos los datos del dataframe de pandas
    dt_heart = pd.read_csv('/home/jhonfypy/CursoML_Scikit_learni_jf/heart.csv')
    print(dt_heart.head(10))  # Imprimimos un encabezado con los primeros 5 registros
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %%
 # Guardamos nuestro dataset sin la columna de target
dt_features = dt_heart.drop(['target'], axis=1)
#este sera nuetro dataset pero sin la columna 
dt_target = dt_heart['target']

#normalizamos los datos 
dt_features = StandardScaler().fit_transform(dt_features)

#paratimos nuetro conjunto para los entrenemientos de prueba Para añadir repicabilidad usamos el random state 
X_train, X_test, y_train, y_test = train_test_split(dt_features, dt_target, test_size=0.3, random_state=42)

# %% [markdown]
# trabajandon con implementecion del kener polinomial

# %%
#implementando nuetro kernel 
kpca = KernelPCA(n_components=4, kernel='poly')#trabajando con polinomios en este caso polinomial 
kpca.fit(X_train)

dt_train = kpca.transform(X_train)
dt_test = kpca.transform(X_test)

logistic = LogisticRegression(solver='lbfgs') #parametros solver 

#etrenando nuetros datos atravez de la funcion fit Eviendo nutros cunjuntos, feacture, tagert de, entrensamiento y 
logistic.fit(dt_train, y_train)
print('SCORE KPCA: ', logistic.score(dt_test, y_test))
# Out:
# SCORE KPCA:  0.7987012987012987

# %% [markdown]
# Trabajandon con la implemetacion del Kernel linear

# %%
#implementando nuetro kernel 
kpca = KernelPCA(n_components=4, kernel='linear')#trabajando con polinomios en este caso linear
kpca.fit(X_train)

dt_train = kpca.transform(X_train)
dt_test = kpca.transform(X_test)

logistic = LogisticRegression(solver='lbfgs') #parametros solver 

#etrenando nuetros datos atravez de la funcion fit Eviendo nutros cunjuntos, feacture, tagert de, entrensamiento y 
logistic.fit(dt_train, y_train)
print('SCORE KPCA: ', logistic.score(dt_test, y_test))
# Out:
# SCORE KPCA:  0.8214285714285714

# %% [markdown]
# Trabajando con la implemetacion del Kerner gaussiana

# %%
#implementando nuetro kernel 
kpca = KernelPCA(n_components=4, kernel='rbf')#trabajando con polinomios en este caso con gaussiana
kpca.fit(X_train)

dt_train = kpca.transform(X_train)
dt_test = kpca.transform(X_test)

logistic = LogisticRegression(solver='lbfgs') #parametros solver 

#etrenando nuetros datos atravez de la funcion fit Eviendo nutros cunjuntos, feacture, tagert de, entrensamiento y 
logistic.fit(dt_train, y_train)
print('SCORE KPCA: ', logistic.score(dt_test, y_test))
# Out:
# SCORE KPCA:  0.8181818181818182

# %% [markdown]
# Notas compañeros
#
# Ahora que ya sabemos para el algoritmo de PCA, ¿que otras alternativas tenemos?
#
# Bueno, una alternativa son los Kernels. Un Kernel es una función matemática que toma mediciones que se comportan de manera no lineal y las proyecta en un espacio dimensional más grande en donde sen linealmente separables.
#
# Y, ¿esto para que puede servir?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sirve para casos en donde no son linealmente separables. El la primera imagen no es posible separarlos con una linea y en la imagen 2 si lo podemos hacer mediante Kernels. Lo que hace la función de Kernels es proyectar los puntos en otra dimensión y así volver los datos linealmente separables.
#
# ¿Que tipo de funciones para Kernels nos podemos encontrar?
#
# ![image.png](attachment:image.png)
#
# Ejemplos de funciones de Kernels en datasets aplicados a un clasificador:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Hola Miguel. Como punto importante, te cuento que el profesor explicó únicamente los kernels usados para el clasificador de Support Vector Machine. El kernel para el SVM ayuda para que los datos que antes no eran separables por una línea o un hiperplano, ahora si lo sean, pero en una dimensión mayor.
#
# Ahora bien, ese fue el kernel que explicó el profesor. Pero no todos los kernels funcionan igual, por ejemplo, los kernels para las redes neuronales convolucionales funcionan de forma distinta y también los kernels para el clasificador de KNN también funcionan de otra manera. Es un punto importante a resaltar 😃

# %%
# Importamos las bibliotecas generales
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
# Importamos los módulos específicos
from sklearn.decomposition import KernelPCA
 
 
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
if __name__ == "__main__":
 # Cargamos los datos del dataframe de pandas
 dt_heart = pd.read_csv('data/heart.csv')
 # Imprimimos un encabezado con los primeros 5 registros
 print(dt_heart.head(5))
 # Guardamos nuestro dataset sin la columna de target
 dt_features = dt_heart.drop(['target'], axis=1)
 # Este será nuestro dataset, pero sin la columna
 dt_target = dt_heart['target']
 # Normalizamos los datos
 dt_features = StandardScaler().fit_transform(dt_features)
  # Partimos el conjunto de entrenamiento y para añadir replicabilidad usamos el random state
 X_train, X_test, y_train, y_test = train_test_split(dt_features, dt_target, test_size=0.3, random_state=42)
 
 #Aplicamos la función de kernel de tipo polinomial
 kpca = KernelPCA(n_components=4, kernel='poly' )
 #Vamos a ajustar los datos
 kpca.fit(X_train)
 
 #Aplicamos el algoritmo a nuestros datos de prueba y de entrenamiento
 dt_train = kpca.transform(X_train)
 dt_test = kpca.transform(X_test)
 
 #Aplicamos la regresión logística un vez que reducimos su dimensionalidad
 logistic = LogisticRegression(solver='lbfgs')
 
 #Entrenamos los datos
 logistic.fit(dt_train, y_train)
 
 #Imprimimos los resultados
 print("SCORE KPCA: ", logistic.score(dt_test, y_test))
